# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
admissionDf = pd.read_csv('Admission_Predict.csv')

# %%
admissionDf.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
admissionDf.set_index('Serial No.', inplace = True)

# %%
admissionDf.isna().sum() #no null values
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
admissionDf.corr() #All values are positively correlated with Chance of admit, no strong cocorrelations
# Out:
#                    GRE Score  TOEFL Score  University Rating       SOP  \
# GRE Score           1.000000     0.835977           0.668976  0.612831
# TOEFL Score         0.835977     1.000000           0.695590  0.657981
# University Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# Chance of Admit     0.802610     0.791594           0.711250  0.675732
#
#                        LOR       CGPA  Research  Chance of Admit
# GRE Score          0.557555  0.833060  0.580391          0.802610
# TOEFL Score        0.567721  0.828417  0.489858          0.791594
# University Rating  0.660123  0.746479  0.447783          0.711250
# ...

# %% [markdown]
# Visualizations

# %%
sns.countplot(admissionDf.Research) #most applicants have research experience

# %%
sns.countplot(admissionDf['University Rating']) #what is the order of university rating?

# %%
sns.distplot(admissionDf['Chance of Admit '], bins = 30);  #Chance of admit is skewed, might need to be normalized for use  with algorithms that have normal distributions

# %%
sns.distplot(admissionDf['GRE Score'], bins = 50)

# %%
sns.distplot(admissionDf['TOEFL Score'], bins = 30) # somehow normal distribution

# %%
sns.countplot(admissionDf['SOP'])

# %%
sns.countplot(admissionDf['LOR '])

# %%
admissionDf.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Chance of Admit '],
#       dtype='object')

# %%
sns.distplot(admissionDf['CGPA'], bins = 30) #kind of normal as well

# %%
sns.scatterplot(data= admissionDf, x = 'GRE Score', y = 'Chance of Admit ');

# %%
sns.scatterplot(data= admissionDf, x = 'TOEFL Score', y = 'Chance of Admit ');

# %%
sns.scatterplot(data= admissionDf, x = 'CGPA', y = 'Chance of Admit ');

# %%
sns.boxplot(data= admissionDf, x = 'University Rating', y = 'Chance of Admit ');

# %%
sns.boxplot(data= admissionDf, x = 'SOP', y = 'Chance of Admit ');

# %%
sns.boxplot(data= admissionDf, x = 'LOR ', y = 'Chance of Admit ');

# %%
sns.boxplot(data= admissionDf, x = 'Research', y = 'Chance of Admit ');
